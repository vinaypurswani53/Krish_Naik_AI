# %%
import os

# %%
# %pwd
# Out:
# '/content'

# %%
import os

# Check if we are currently in the 'research' directory
if os.getcwd().endswith("research"):
    os.chdir("../")
    print(f"✅ Successfully moved to Project Root: {os.getcwd()}")
else:
    print(f"ℹ️ Already in Root: {os.getcwd()}")
# Out:
# ℹ️ Already in Root: /
